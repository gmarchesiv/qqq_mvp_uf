# %%
from config.vars.rutina import varsRutina


vars = varsRutina(debug_mode=True  )

# %%
vars

# %%
vars.askbid_call_prom=list(vars.askbid_call_prom)
vars.askbid_put_prom=list(vars.askbid_put_prom)
vars.name=""
vars.wallet=""
vars.date= ""
vars.time= ""
vars.trade_hour= ""

# %%
data=vars.__dict__

# %%
data=vars.__dict__.copy()

# %%
data
# Out:
# {'data': {},
#  'name': '',
#  'wallet': '',
#  'conexion': False,
#  'ready': False,
#  'flag_alerta': False,
#  'fecha': '',
#  'date': '',
#  'time': '',
#  'trades': [],
#  'flag_bloqueo_tiempo': False,
#  'bloqueo': True,
#  'accion_mensaje': 0,
#  'exchange': 'CBOE',
#  'hora_inicio': '',
#  'status': 'ON',
#  'df': None,
#  'i': 0,
#  'minutos': 0,
#  'n_minutos': 0,
#  'minutos_trade': 0,
#  'vix': 0,
#  'price': 0,
#  'exp': '',
#  'quantity': 0,
#  'priceBuy': 0,
#  'real_priceBuy': 0,
#  'params_regla': '',
#  'rentabilidad': 0,
#  'rentabilidad_ant': 0,
#  'regla': '',
#  'ugs_n': 0,
#  'ugs_n_ant': 0,
#  'pico': 0,
#  'tipo': '',
#  'call_dic': {},
#  'put_dic': {},
#  'caida': 0,
#  'trade_hour': '',
#  'regla_ant': '',
#  'strike_c': 0,
#  'dcall': 0,
#  'docall': 0,
#  'askbid_call': 0,
#  'askbid_call_prom': [],
#  'call_close': 0,
#  'call_open': 0,
#  'cask': 0,
#  'cbid': 0,
#  'price_Call_label': 0,
#  'd_Call_label': 0,
#  'promedio_call': 0,
#  'strike_p': 0,
#  'dput': 0,
#  'doput': 0,
#  'doput_ant': 0,
#  'askbid_put': 0,
#  'askbid_put_prom': [],
#  'put_close': 0,
#  'put_open': 0,
#  'pask': 0,
#  'pbid': 0,
#  'price_Put_label': 0,
#  'd_Put_label': 0,
#  'promedio_put': 0,
#  'call': False,
#  'put': False,
#  'compra': True,
#  'flag_real_priceBuy': False,
#  'rule': True,
#  'flag_Call_R2': False,
#  'flag_Put_R2': False,
#  'flag_cambio_R1_label': False,
#  'flag_Call_label_cambio': False,
#  'flag_Call_label_1_compra': False,
#  'flag_Call_label_2_compra': False,
#  'flag_Call_reset': {'R1': False,
#   'R1-3': False,
#   'R1-E': False,
#   'R1-E2': False,
#   'INV': False,
#   'R1-C': False,
#   'F1': False,
#   'FAST_2': False},
#  'flag_Put_reset': {'FAST': False,
#   'R2-FAST': False,
#   'R2': False,
#   'R2-E': False,
#   'R3': False},
#  'flag_Put_reset_esc': {'LABEL-1': False, 'LABEL-2': False},
#  'flag_cambio_fast': False,
#  'flag_Put_label_cambio': False,
#  'flag_bloqueo_put': False,
#  'flag_bloqueo_r1_e': False}

# %%
import json

print()

# %%
with open("vars.json", "w") as json_file:
        json.dump(data, json_file, indent=4)
